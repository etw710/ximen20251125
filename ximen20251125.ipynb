# %% [markdown]
# <a href="https://colab.research.google.com/github/etw710/ximen20251125/blob/main/ximen20251125.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# 3

# %% [markdown]
# 說明文件是 markdown語法 | 可以了解一下
#
# Jupyter notebook 支援 latex math
#
# $ \frac{1}{4} \pi r^2 $
